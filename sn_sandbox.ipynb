# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv("C:/Users/jacob.carey/Desktop/data_sandbox/eu_sn_pull_no_altcon_singleday.csv", header=0, 
                 usecols=["date","companyid","noticeid","countryname","countryid","noticeid","domain",
                          "host","totalhits","consentgivencount","noconsentgivencount","uniqueusercount",
                          "impressions","consent","altconsent"])

# %%
df.describe()
# Out:
#          companyid      noticeid   countryid      totalhits  \
# count   267.000000    267.000000  267.000000     267.000000
# mean   3656.108614  12392.681648   13.191011    6563.730337
# std    1917.923711   4939.296531   10.853304   18766.282917
# min      53.000000    399.000000    3.000000     191.000000
# 25%    2020.000000   7862.000000    5.000000     545.500000
# 50%    4601.000000  15137.000000    7.000000    1085.000000
# 75%    5278.000000  15815.000000   22.000000    3670.500000
# max    6168.000000  17252.000000   61.000000  187656.000000
#
#        consentgivencount  noconsentgivencount  uniqueusercount   impressions  \
# count         267.000000           267.000000       267.000000    267.000000
# mean         2152.749064          4410.981273      1019.760300   3580.131086
# std          6941.187610         12381.887428      3311.656941   9970.609138
# min             1.000000           173.000000        51.000000    107.000000
# ...

# %%
df.sort_values(by=["totalhits"], ascending=False)
# Out:
#            date  companyid  noticeid         countryname  countryid  \
# 103  2019-05-08        660      3421      United Kingdom          6
# 134  2019-05-08       5278     14285               Spain          4
# 194  2019-05-08       2020     15446               Spain          4
# 168  2019-05-08       6168     15588            Portugal         26
# 71   2019-05-08       5278      3273      United Kingdom          6
# 259  2019-05-08       5278     14286               Spain          4
# 47   2019-05-08       5278     10858      United Kingdom          6
# 228  2019-05-08       5278     14287               Spain          4
# 233  2019-05-08       5278     14473         Netherlands          8
# 209  2019-05-08       1558     16062               Italy          7
# 160  2019-05-08       6168     15541             Hungary         24
# 206  2019-05-08       1558     15402               Spain          4
# 97   2019-05-08        660      3421             Germany          3
# ...

# %%
us_df = pd.DataFrame(df[df["countryname"]=="United States"])

# %%
us_df["domain"].unique()
# Out:
# array(['axe.com', 'drhorton.com', 'goldbach.com',
#        'hourglasscosmetics.com', 'jerrys.es', 'lemans.org',
#        'mashable.com', 'nespresso.com', 'nestlecocina.es',
#        'pukkaherbs.com'], dtype=object)

# %%
us_df.head(30)
# Out:
#            date  companyid  noticeid    countryname  countryid  \
# 4    2019-05-08       4601     16037  United States          4
# 51   2019-05-08       4960     14351  United States          6
# 59   2019-05-08       5351     13230  United States         19
# 64   2019-05-08       4601     16091  United States          6
# 87   2019-05-08       4601     15456  United States          4
# 91   2019-05-08       4389     14093  United States          5
# 99   2019-05-08        660      3421  United States          3
# 104  2019-05-08        660      3421  United States          6
# 154  2019-05-08       6168     15533  United States         19
# 155  2019-05-08       6168     15534  United States         20
# 158  2019-05-08       6168     15539  United States          5
# 159  2019-05-08       6168     15541  United States         24
# 163  2019-05-08       6168     15573  United States          6
# 165  2019-05-08       6168     15574  United States          8
# ...
