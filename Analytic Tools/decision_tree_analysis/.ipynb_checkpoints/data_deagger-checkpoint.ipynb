# %%
import pandas as pd

# %%
my_df = pd.read_csv("C:/Users/jacob.carey/Downloads/unilever_nl_data.csv", header=0, encoding='utf-8',
                             usecols=["monat","companyid","noticeid","countryid","domain","host",
                                      "uniqueusercount","impressions","consent"])

# %%
newlist = []
sample_ratio = 100

# %%
my_df.head(25)
# Out:
#       monat  companyid  noticeid  countryid                domain  \
# 0   2018-12       4601      5513          8           andrelon.nl
# 1   2018-12       4601     13022          8               axe.com
# 2   2018-12       4601      5515          8              becel.nl
# 3   2018-12       4601      5516          8      becelproactiv.nl
# 4   2018-12       4601      5516          8      becelproactiv.nl
# 5   2018-12       4601      5516          8      becelproactiv.nl
# 6   2018-12       4601      5519          8           benjerry.nl
# 7   2018-12       4601      5520          8           bertolli.nl
# 8   2018-12       4601      2312          8              bing.com
# 9   2018-12       4601      5521          8           blueband.nl
# 10  2018-12       4601      5522          8               bona.nl
# 11  2018-12       4601      5523          8              calve.nl
# 12  2018-12       4601      7032          8       cleanipedia.com
# 13  2018-12       4601     12805          8           conimex.com
# 14  2018-12       4601      5524          8            conimex.nl
# 15  2018-12       4601      5524          8            conimex.nl
# 16  2018-12       4601      2312          8              croma.nl
# 17  2018-12       4601      5526          8              croma.nl
# 18  2018-12       4601      5529          8           cupasoup.nl
# 19  2018-12       4601      5527          8  cupasoupophetwerk.nl
# 20  2018-12       4601      5530          8              dove.com
# 21  2018-12       4601      5532          8          florafood.nl
# 22  2018-12       4601      5534          8          hellmanns.nl
# 23  2018-12       4601      5533          8          hertogijs.nl
# 24  2018-12       4601      5537          8             knorr.com
#
#                                         host  uniqueusercount  impressions  \
# 0                            www.andrelon.nl            37421       167097
# 1                                www.axe.com            14222       181881
# 2                               www.becel.nl            26199       100316
# 3           www.preferences.becelproactiv.nl              830         2369
# 4                       www.becelproactiv.nl            27307       149063
# 5   healthcareprofessionals.becelproactiv.nl             1025        14845
# 6                            www.benjerry.nl               53          266
# 7                            www.bertolli.nl            17887        90945
# 8                               www.bing.com               57           80
# 9                            www.blueband.nl            61703       201105
# 10                               www.bona.nl              301         2591
# 11                              www.calve.nl            23887       105989
# 12                       www.cleanipedia.com            15926        78457
# 13                           www.conimex.com              893         5375
# 14                            www.conimex.nl            60334       317162
# 15                www.preferences.conimex.nl              100          342
# 16                              www.croma.nl           173767       701433
# 17                              www.croma.nl             4997        20190
# 18                           www.cupasoup.nl             2676        25905
# 19                  www.cupasoupophetwerk.nl              718         4464
# 20                              www.dove.com            15086        97230
# 21                          www.florafood.nl              389         2309
# 22                          www.hellmanns.nl             5891        19450
# 23                          www.hertogijs.nl            51975       213932
# 24                             www.knorr.com            78779       391896
#
#     consent
# 0     20695
# 1       808
# 2     20607
# 3       214
# 4     20378
# 5       838
# 6        38
# 7     13521
# 8        49
# 9     47478
# 10      163
# 11     9737
# 12    11091
# 13      606
# 14    44503
# 15       36
# 16   127943
# 17     3008
# 18     2075
# 19      361
# 20     6810
# 21      281
# 22     3274
# 23    30767
# 24    51480

# %%
for row in my_df.iterrows():
    my_dict = dict(row[1])
    
    #Cleaning up data types and data values
    
    #format Country to numeric value
    test_val = my_dict.get('Country', 0).lower().strip()
    if test_val == 'uk': 
        my_dict['Country'] = 1
    elif test_val == 'united kingdom': 
        my_dict['Country'] = 1
    elif test_val == 'france': 
        my_dict['Country'] = 2
    elif test_val == 'germany': 
        my_dict['Country'] = 3
    
    #format OnBrand to numeric value 
    test_val = my_dict.get('OnBrand', 0).lower().strip()
    if test_val == 'no': 
        my_dict['OnBrand'] = 1
    elif test_val == 'yes': 
        my_dict['OnBrand'] = 2
    elif test_val == 'partial': 
        my_dict['OnBrand'] = 3

    
    #format LanguageStyle to numeric value
    test_val = my_dict.get('LanguageStyle', 0).lower().strip()
    if test_val == '?': 
        my_dict['LanguageStyle'] = 99
    elif test_val == 'unclear': 
        my_dict['LanguageStyle'] = 0
    elif test_val == 'clear': 
        my_dict['LanguageStyle'] = 1

    
    #copies my_dict, removes Users and Consent, 
    #fills newlist with consenting and nonconsenting samples / sample_ratio
    #creates dataframe new_df with user samples 
    c_dict = my_dict.copy()
    del c_dict['Users']
    del c_dict['Consent']
    c_dict['Consent_bool'] = 1
    for idx in range(int(my_dict['Consent']/sample_ratio)):     
        newlist.append(c_dict)
    nc_dict = c_dict.copy()
    nc_dict['Consent_bool'] = 0
    nc_count = my_dict['Users'] - my_dict['Consent']
    for idx in range(int(nc_count/sample_ratio)):
        newlist.append(nc_dict)

# %%
new_df = pd.DataFrame(newlist)

# %%
#new_df.head()

# %%
new_df.to_csv(path_or_buf="C:/Users/jacob.carey/Desktop/SiteNotice Consent Rate Analysis/ConsentDataOutput_{0}.csv".format(sample_ratio))

# %%
new_df.count()
# Out:
# ConsentDurationMonths      857909
# ConsentRequired            857909
# ConsentType                857909
# Consent_bool               857909
# Country                    857909
# LanguageStyle              857909
# NavigateConsentEnabled     857909
# OnBrand                    857909
# PageClickConsentEnabled    857909
# ScrollConsentEnabled       857909
# dtype: int64

# %%
new_df.head()
# Out:
#    ConsentDurationMonths  ConsentRequired  ConsentType  Consent_bool  Country  \
# 0                     13                1            2             1        1
# 1                     13                1            2             1        1
# 2                     13                1            2             1        1
# 3                     13                1            2             1        1
# 4                     13                1            2             1        1
#
#    LanguageStyle  NavigateConsentEnabled  OnBrand  PageClickConsentEnabled  \
# 0              1                       0        2                        0
# 1              1                       0        2                        0
# 2              1                       0        2                        0
# 3              1                       0        2                        0
# 4              1                       0        2                        0
#
#    ScrollConsentEnabled
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
new_df.columns
# Out:
# Index(['ConsentDurationMonths', 'ConsentRequired', 'ConsentType',
#        'Consent_bool', 'Country', 'LanguageStyle', 'NavigateConsentEnabled',
#        'OnBrand', 'PageClickConsentEnabled', 'ScrollConsentEnabled'],
#       dtype='object')

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=857909, step=1)
