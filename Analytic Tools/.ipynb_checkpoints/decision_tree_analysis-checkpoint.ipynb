# %%
import pandas as pd

# %%
my_df = pd.read_csv("C:/Users/jacob.carey/Desktop/consent_data_fixed.csv", header=0, encoding='utf-8',
                             usecols=['Country', 
                                      'Users', 
                                      'Consent', 
                                      'OnBrand', 
                                      'LanguageStyle', 
                                      'ConsentType', 
                                      #'ConsentDurationMonths',
                                      #'ScrollConsentEnabled', 
                                      #'PageClickConsentEnabled',
                                      #'NavigateConsentEnabled',
                                      #'ConsentRequired'
                                     ])

# %%
newlist = []
sample_ratio = 1

# %%
my_df.head()
# Out:
#           Country   Users  Consent  OnBrand LanguageStyle  ConsentType  \
# 0  United Kingdom   74592    61856      Yes         Clear            2
# 1  United Kingdom  302870   238757      Yes         Clear            2
# 2  United Kingdom  229751   126105  Partial         Clear            2
# 3  United Kingdom  202540   122114  Partial         Clear            2
# 4  United Kingdom  410787   263955  Partial         Clear            2
#
#    ConsentDurationMonths  ScrollConsentEnabled  PageClickConsentEnabled  \
# 0                     13                     0                        0
# 1                     13                     0                        0
# 2                     13                     0                        0
# 3                     13                     0                        0
# 4                     13                     0                        0
#
#    NavigateConsentEnabled  ConsentRequired
# 0                       0                1
# 1                       1                1
# 2                       1                1
# 3                       1                1
# 4                       1                1

# %%
for row in my_df.iterrows():
    my_dict = dict(row[1])
    
    #Cleaning up data types and data values
    
    #format Country to numeric value
    test_val = my_dict.get('Country', 0).lower().strip()
    if test_val == 'uk': 
        my_dict['Country'] = 1
    elif test_val == 'united kingdom': 
        my_dict['Country'] = 1
    elif test_val == 'france': 
        my_dict['Country'] = 2
    elif test_val == 'germany': 
        my_dict['Country'] = 3
    
    #format OnBrand to numeric value 
    test_val = my_dict.get('OnBrand', 0).lower().strip()
    if test_val == 'no': 
        my_dict['OnBrand'] = 1
    elif test_val == 'yes': 
        my_dict['OnBrand'] = 2
    elif test_val == 'partial': 
        my_dict['OnBrand'] = 3

    
    #format LanguageStyle to numeric value
    test_val = my_dict.get('LanguageStyle', 0).lower().strip()
    if test_val == '?': 
        my_dict['LanguageStyle'] = 99
    elif test_val == 'unclear': 
        my_dict['LanguageStyle'] = 0
    elif test_val == 'clear': 
        my_dict['LanguageStyle'] = 1

    
    #copies my_dict, removes Users and Consent, 
    #fills newlist with consenting and nonconsenting samples / sample_ratio
    #creates dataframe new_df with user samples 
    c_dict = my_dict.copy()
    del c_dict['Users']
    del c_dict['Consent']
    c_dict['Consent_bool'] = 1
    for idx in range(int(my_dict['Consent']/sample_ratio)):     
        newlist.append(c_dict)
    nc_dict = c_dict.copy()
    nc_dict['Consent_bool'] = 0
    nc_count = my_dict['Users'] - my_dict['Consent']
    for idx in range(int(nc_count/sample_ratio)):
        newlist.append(nc_dict)

# %%
new_df = pd.DataFrame(newlist)

# %%
#new_df.head()

# %%
new_df.to_csv(path_or_buf="C:/Users/jacob.carey/Desktop/ConsentDataOutput_{0}.csv".format(sample_ratio))

# %%
new_df.count()
# Out:
# ConsentType      85832663
# Consent_bool     85832663
# Country          85832663
# LanguageStyle    85832663
# OnBrand          85832663
# dtype: int64

# %%
new_df.head()
# Out:
#    ConsentDurationMonths  ConsentRequired  ConsentType  Consent_bool  Country  \
# 0                     13                1            2             1        1
# 1                     13                1            2             1        1
# 2                     13                1            2             1        1
# 3                     13                1            2             1        1
# 4                     13                1            2             1        1
#
#    LanguageStyle  NavigateConsentEnabled  OnBrand  PageClickConsentEnabled  \
# 0              1                       0        2                        0
# 1              1                       0        2                        0
# 2              1                       0        2                        0
# 3              1                       0        2                        0
# 4              1                       0        2                        0
#
#    ScrollConsentEnabled
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
