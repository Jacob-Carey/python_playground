# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/jacob.carey/Documents/consentv2/ba_pull.csv", header=0, usecols={
"Id",
"company_name",
"Domain",
"SiteNoticeThemeId",
"Industry",
"ConsentToolThemeId",
"ConsentDisplayTypeId",
"IncludeSubdomains",
"ConsentTypeId",
"PrivacyAccessTypeId",
"ConsentDurationMonths",
"L2Enabled",
"GDPREnabled",
"IABEnabled",
"ConsentDetailCategories",
"ConsentDetailVendors",
"AdChoicesEnabled",
"CountryId",
"country_name",
"Identifier",
'Screenshot',
'OnBrand',
'LanguageIsClear'
})

# %%
newlist = []

# %%
df['country'] = 0

# %%
for row in df.iterrows():
    dic = dict(row[1])
    
    test_val = dic['country_name'].strip()
    if test_val == 'Canada':
        dic['country'] = 1
    elif test_val == 'United States':
        dic['country'] = 2
    elif test_val == 'Romania':
        dic['country'] = 3
    elif test_val == 'Austria':
        dic['country'] = 4
    elif test_val == 'United Kingdom':
        dic['country'] = 5
    elif test_val == 'Belgium':
        dic['country'] = 6
    elif test_val == 'France':
        dic['country'] = 7
    elif test_val == 'Greece':
        dic['country'] = 8
    elif test_val == 'Bulgaria':
        dic['country'] = 9
    elif test_val == 'Australia':
        dic['country'] = 10
    elif test_val == 'Spain':
        dic['country'] = 11
    elif test_val == 'Hungary':
        dic['country'] = 12
    elif test_val == 'Germany':
        dic['country'] = 13
    elif test_val == 'Czech Republic':
        dic['country'] = 14
    elif test_val == 'Portugal':
        dic['country'] = 15
    elif test_val == 'Italy':
        dic['country'] = 16
    elif test_val == 'Denmark':
        dic['country'] = 17
    elif test_val == 'Poland':
        dic['country'] = 18
    elif test_val == 'Netherlands':
        dic['country'] = 19
    elif test_val == 'Russia':
        dic['country'] = 20
    elif test_val == 'Sweden':
        dic['country'] = 21
    elif test_val == 'Finland':
        dic['country'] = 22
    elif test_val == 'Ireland':
        dic['country'] = 23
    elif test_val == 'Luxembourg':
        dic['country'] = 24
    elif test_val == 'Slovakia':
        dic['country'] = 25
    elif test_val == 'Lithuania':
        dic['country'] = 26
    elif test_val == 'Estonia':
        dic['country'] = 27
    elif test_val == 'Latvia':
        dic['country'] = 28
    elif test_val == 'Slovenia':
        dic['country'] = 29
    elif test_val == 'Croatia':
        dic['country'] = 30

# %%
df.head()
# Out:
#    AdChoicesEnabled  ConsentDetailCategories  ConsentDetailVendors  \
# 0                 1                        0                     0
# 1                 1                        0                     0
# 2                 1                        0                     0
# 3                 1                        0                     0
# 4                 1                        0                     0
#
#    ConsentDisplayTypeId  ConsentDurationMonths  ConsentToolThemeId  \
# 0                     1                     13                 117
# 1                     1                     13                 117
# 2                     1                     13                 117
# 3                     1                     13                  91
# 4                     1                     13                  91
#
#    ConsentTypeId  CountryId                    Domain  GDPREnabled  ...  \
# 0              3          9    echosignawspreview.com            0  ...
# ...
